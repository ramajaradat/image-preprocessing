# %%
# import lib
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## img contoring

# %%
handwriten=cv2.imread("./data/handwriten.png")
plt.imshow(handwriten[:,:,::-1])

# %%
b=cv2.imread("./data/b.png")
plt.imshow(b[:,:,::-1])
