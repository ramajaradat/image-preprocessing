# %%
import numpy as numpy
from  skimage.io import imread
import matplotlib.pyplot as plt
import skimage

# %%
skimage.__version__
# Out:
# '0.22.0'

# %%
img_flower=imread("./data/flowers.png")

# %%
plt.matshow(img_flower)
# مثل مو ملاحظين الصورةبتطاع مباشرة بنفس اللون بسبب انه 
#functionality in skimge like matplot show the imge with original color without do slicing
#skimge direct acsses RGB

# %%
#convert to BGR with slice
plt.matshow(img_flower[:,:,::-1],cmap='grey')
#no change with color when using cmap because the functionality of skimg lib

# %%
img_flower.shape
# Out:
# (480, 817, 3)

# %%
img_flower
# Out:
# array([[[184, 193, 202],
#         [184, 193, 202],
#         [184, 193, 200],
#         ...,
#         [107, 102,  98],
#         [107, 102,  98],
#         [106, 101,  97]],
#
#        [[184, 193, 202],
#         [184, 193, 202],
#         [184, 193, 200],
#         ...,
#         [108, 103,  99],
#         [107, 102,  98],
#         [109, 104, 100]],
#
#        [[184, 193, 202],
#         [184, 193, 202],
#         [184, 193, 200],
#         ...,
#         [108, 103,  99],
#         [108, 103,  99],
#         [110, 105, 101]],
#
#        ...,
#
#        [[191, 192, 186],
#         [191, 192, 186],
#         [190, 191, 185],
#         ...,
#         [ 52,  72,   0],
#         [ 52,  72,   0],
#         [ 51,  71,   0]],
#
#        [[191, 192, 186],
#         [191, 192, 186],
#         [190, 191, 185],
#         ...,
#         [ 52,  72,   0],
#         [ 52,  72,   0],
#         [ 52,  72,   1]],
#
#        [[191, 192, 186],
#         [191, 192, 186],
#         [190, 191, 185],
# ...

# %%
img_flower.max(),img_flower.min()
# Out:
# (255, 0)

# %% [markdown]
# ## convert color img to non color img

# %%
#convert RGB to LAB
from skimage.color import rgb2lab,la
#img_flower_lab=skimage.c
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 #convert RGB to LAB
# ----> 2 from skimage.color import rgb2lab,la
#       3 #img_flower_lab=skimage.c
#
# ImportError: cannot import name 'la' from 'skimage.color' (c:\Users\user\Desktop\mycv\.venv\Lib\site-packages\skimage\color\__init__.py)
